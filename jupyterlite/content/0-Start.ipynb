# %% [markdown]
# # Konfidenzintervalle – ein Baukasten
#
# Die Materialien verbinden zwei Zugänge:
#
# | GeoGebra | Python |
# |:--|:--|
# | schnell entdecken und variieren | transparent, reproduzierbar und gezielt verändern |
#
# **GeoGebra öffnet den Raum zum Entdecken. Python macht den Weg transparent und reproduzierbar.**
#
# Die Dateien können einzeln verwendet oder zu einem Lernweg verbunden werden. Die folgende Reihenfolge ist ein Vorschlag – keine Vorgabe.

# %% [markdown]
# ## Python-Notebooks: ein möglicher Lernweg
#
# ### 1. Von der Simulation zur Verteilung - Prognoseintervalle entdecken
#
# 1. [Empirische Verteilung der relativen Häufigkeit $H=X/n$](01-Empirische-H-Verteilung.ipynb)
#    Wiederholte Stichproben als Dotplot; auf Wunsch mit Prognoseintervall und markierten Punkten außerhalb.
#
# 2. [Verteilung der relativen Häufigkeit $H=X/n$](02-Binomialverteilung-H.ipynb)
#    Exakte Binomialverteilung von $H$ und ihre diskreten möglichen Werte $h=k/n$.
#
#
# ### 2. Vom Prognose- zum Konfidenzintervall
#
# 3. [Konfidenzellipse und Wilson-Intervall](03-Wilson-Konfidenzellipse.ipynb)
#    Vom Prognoseband im $(p,h)$-Raum durch Inversion zum Wilson-Konfidenzintervall.
#
# 4. [Verfahrenswahrscheinlichkeit bei festem $p_0$](04-Verfahrenswahrscheinlichkeit-p0.ipynb)
#    Dieselben Stichproben in zwei Blickrichtungen: Realisationen von $H$ und die zugehörigen Wilson-Intervalle.
#
# 5. [Verfahrenswahrscheinlichkeit: Wilson-Konfidenzintervalle](05-Verfahrenswahrscheinlichkeit-Wilson-Intervalle.ipynb)
#    Die Intervallgrafik für sich: Überdeckung und Nichtüberdeckung als Denkraum.
#
# ### 3. Verfahren vergleichen
#
# 6. [Drei Binomial-Konfidenzintervalle im Vergleich](06-Konfidenzintervalle-Vergleich.ipynb)
#    Reine Berechnung von Wald-, Wilson- und Clopper-Pearson-Intervall.
#
# ### 4. Grafik zu einer Abituraufgabe
#
# 7. [Nahaufnahme im $(p,h)$-Raum](07-Nahaufnahme-ph-Raum.ipynb)
#    Die Diskretheit von $H=k/n$ in der Nahaufnahme; Lösungshinweis zu einer Aufgabe aus dem IQB-Pool 2025.

# %% [markdown]
# ## GeoGebra-Dateien
#
# Die GeoGebra-Dateien sind vor allem zum unmittelbaren Entdecken und Variieren gedacht.
#
# Alle GeoGebra-Dateien sind außerdem über die [gemeinsame Auswahlseite](https://rveh.github.io/geogebra-python/) erreichbar.
#
# | Datei | Schwerpunkt |
# |:--|:--|
# | [KI freirubbeln](KI-freirubbeln.ggb) | Ein Konfidenzintervall schrittweise sichtbar machen |
# | [KI mit Zollstock handelnd entdecken](Zollstock.ggb) | Eine digitale Ergänzung des Zollstockexperiments zum Entdecken eines Konfidenzintervalls; die Variabilität des Zollstocks wird sichtbar |
# | [Verteilung der relativen Häufigkeit $H=X/n$](Prognoseintervalle_einzeln.ggb) | Realisationen $h_i$ der relativen Häufigkeit $H=X/n$ werden Schritt für Schritt erzeugt und als DotPlot ausgegeben. Das zugehörige Prognoseintervall kann eingeblendet werden. |
# | [Verteilung der relativen Häufigkeit $H=X/n$](Prognoseintervalle_gesamt.ggb) | Realisationen $h_i$ der relativen Häufigkeit $H=X/n$ werden für eine vorgegebene Anzahl an Wiederholungen ergzeugt und als DotPlot ausgegeben. Das zugehörige Prognoseintervall kann eingeblendet werden.|
# | [Wilson-Konfidenzellipe](WaldWilsonBerechnungen.ggb) | Die Konfidenzellipse wird mit einigen Prognoseintervallen angezeigt und das Wilson-Konfidenzintervall berechntet. Zusätzlich wird das zugehörige Wald-Konfidenzintervall berechnet.|
# | [Verfahrenswahrscheinlichkeit](Verfahrenswkeit.ggb) | Wiederholte Stichproben und Überdeckung erkunden. Dieselben Stichproben in zwei Blickrichtungen: Realisationen von $H$ und die zugehörigen Wilson-Intervalle. |

# %% [markdown]
# ## Arbeiten in JupyterLite
#
# 1. Ein Notebook über den Link öffnen.
# 2. Nur die Zelle **Eingaben** verändern.
# 3. Anschließend alle Zellen von oben nach unten ausführen.
# 4. In den Grafik-Notebooks werden mit `save_figure = True` PNG- und PDF-Dateien gespeichert. Der Unterordner `fig/` wird bei Bedarf automatisch angelegt.
#
# Ein fest eingestellter `seed` macht Simulationen reproduzierbar. Alle Notebooks trennen Eingaben, Prüfung, Berechnung, Grafik und Ausgabe sichtbar voneinander.
